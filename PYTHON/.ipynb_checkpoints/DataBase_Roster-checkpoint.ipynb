# %%
import json
import sqlite3

# %%
conn = sqlite3.connect(R"C:\Users\Mateus Joter\Desktop\Aprender\DATABASES\rosterdb.sqlite")
cur = conn.cursor()

# %%
# Do some setup
cur.executescript('''
DROP TABLE IF EXISTS User;
DROP TABLE IF EXISTS Member;
DROP TABLE IF EXISTS Course;

CREATE TABLE User (
    id     INTEGER PRIMARY KEY,
    name   TEXT UNIQUE
);

CREATE TABLE Course (
    id     INTEGER PRIMARY KEY,
    title  TEXT UNIQUE
);

CREATE TABLE Member (
    user_id     INTEGER,
    course_id   INTEGER,
    role        INTEGER,
    PRIMARY KEY (user_id, course_id)
)
''')

# %%
fname = input('Enter file name: ')
if len(fname) < 1:
    fname = R"C:\Users\Mateus Joter\Downloads\roster_data.json"

#   [ "Charley", "si110", 1 ],
#   [ "Mea", "si110", 0 ],

str_data = open(fname).read()
json_data = json.loads(str_data)
# Out:
# Enter file name:

# %%
for entry in json_data:

    name = entry[0]
    title = entry[1]
    role = entry[2]

    print((name, title, role))

    cur.execute('''INSERT OR IGNORE INTO User (name)
        VALUES ( ? )''', ( name, ) )
    cur.execute('SELECT id FROM User WHERE name = ? ', (name, ))
    user_id = cur.fetchone()[0]

    cur.execute('''INSERT OR IGNORE INTO Course (title)
        VALUES ( ? )''', ( title, ) )
    cur.execute('SELECT id FROM Course WHERE title = ? ', (title, ))
    course_id = cur.fetchone()[0]

    cur.execute('''INSERT OR REPLACE INTO Member
        (user_id, course_id, role) VALUES ( ?, ?, ? )''',
        ( user_id, course_id, role ) )

    conn.commit()
# Out:
# ('Rhian', 'si110', 1)
# ('Kaydin', 'si110', 0)
# ('Jon', 'si110', 0)
# ('Selasi', 'si110', 0)
# ('Logyne', 'si110', 0)
# ('Zacharie', 'si110', 0)
# ('Muryam', 'si110', 0)
# ('Mack', 'si110', 0)
# ('Cullen', 'si110', 0)
# ('Prabhjoit', 'si110', 0)
# ('Cabhan', 'si110', 0)
# ('Matia', 'si110', 0)
# ('Bismah', 'si110', 0)
# ('Mikayla', 'si110', 0)
# ('Amieleigh', 'si110', 0)
# ('Kyna', 'si110', 0)
# ('Muireann', 'si110', 0)
# ('Kym', 'si110', 0)
# ('Urban', 'si110', 0)
# ('Francesco', 'si110', 0)
# ('Nairne', 'si110', 0)
# ('Deagan', 'si110', 0)
# ('McKade', 'si110', 0)
# ('Harjyot', 'si110', 0)
# ('Patsy', 'si110', 0)
# ('Kallan', 'si110', 0)
# ('Nikiya', 'si110', 0)
# ('Honey', 'si110', 0)
# ('Zuriel', 'si110', 0)
# ('Madox', 'si110', 0)
# ('Blake', 'si110', 0)
# ('Nikodem', 'si110', 0)
# ('Kaidy', 'si110', 0)
# ('Sidra', 'si110', 0)
# ('Kirstyn', 'si110', 0)
# ('Baillie', 'si110', 0)
# ('Iseabel', 'si110', 0)
# ('Deonaid', 'si106', 1)
# ('Amrita', 'si106', 0)
# ('Mali', 'si106', 0)
# ('Jostelle', 'si106', 0)
# ('Chelsy', 'si106', 0)
# ('Izabella', 'si106', 0)
# ('Sheignneth', 'si106', 0)
# ('Evelyn', 'si106', 0)
# ('Caethan', 'si106', 0)
# ('Daksh', 'si106', 0)
# ('Melice', 'si106', 0)
# ('Cadhla', 'si106', 0)
# ('Freddie', 'si106', 0)
# ('Dilsa', 'si106', 0)
# ('Liesje', 'si106', 0)
# ('Teo', 'si106', 0)
# ('Celik', 'si106', 0)
# ('Claudia', 'si106', 0)
# ('Ceilidh', 'si106', 0)
# ('Mael', 'si106', 0)
# ('Damian', 'si106', 0)
# ('Aristotelis', 'si106', 0)
# ('Derron', 'si106', 0)
# ('Oriane', 'si106', 0)
# ('Caden', 'si106', 0)
# ('Jaymi', 'si106', 0)
# ('Paolo', 'si106', 0)
# ('Hazel', 'si106', 0)
# ('Kaylin', 'si106', 0)
# ('Bobby', 'si106', 0)
# ('Capree', 'si106', 0)
# ('Soukina', 'si106', 0)
# ('Nodoka', 'si106', 0)
# ('Hadiyah', 'si106', 0)
# ('Sinai', 'si106', 0)
# ('Nelly', 'si106', 0)
# ('Marcy', 'si106', 0)
# ('Zainib', 'si106', 0)
# ('Tammie', 'si106', 0)
# ('Cairn', 'si106', 0)
# ('Laurie', 'si106', 0)
# ('Asia', 'si106', 0)
# ('Geoff', 'si106', 0)
# ('Yoji', 'si106', 0)
# ('Kruz', 'si106', 0)
# ('Zosia', 'si106', 0)
# ('Eiddon', 'si106', 0)
# ('Colby', 'si106', 0)
# ('Nelson', 'si106', 0)
# ('Tieghan', 'si106', 0)
# ('Micall', 'si206', 1)
# ('Eljay', 'si206', 0)
# ('Taira', 'si206', 0)
# ('Kingston', 'si206', 0)
# ('Kayleb', 'si206', 0)
# ('Jenni', 'si206', 0)
# ('Sabrina', 'si206', 0)
# ('Camille', 'si206', 0)
# ('Kaleena', 'si206', 0)
# ('Suman', 'si206', 0)
# ('Kaelum', 'si206', 0)
# ('Sadie', 'si206', 0)
# ('Reid', 'si206', 0)
# ('Divine', 'si206', 0)
# ('Malikah', 'si206', 0)
# ('Ashtyn', 'si206', 0)
# ('Cecily', 'si206', 0)
# ('Riley', 'si206', 0)
# ('Reilly', 'si206', 0)
# ('Anndra', 'si206', 0)
# ('Christie', 'si206', 0)
# ('Jarred', 'si206', 0)
# ('Gil', 'si206', 0)
# ('Talise', 'si206', 0)
# ('Alise', 'si206', 0)
# ('Jared', 'si206', 0)
# ('Lucille', 'si206', 0)
# ('Azaan', 'si206', 0)
# ('Muir', 'si206', 0)
# ('Nabiha', 'si206', 0)
# ('Oluwafikunayomi', 'si206', 0)
# ('Cahlum', 'si206', 0)
# ('Annaleigh', 'si206', 0)
# ('Jakub', 'si206', 0)
# ('Cora', 'si206', 0)
# ('Hussan', 'si206', 0)
# ('Walid', 'si206', 0)
# ('Elsa', 'si206', 0)
# ('Talia', 'si206', 0)
# ('Keela', 'si206', 0)
# ('Faizaan', 'si206', 0)
# ('Krish', 'si206', 0)
# ('Joris', 'si206', 0)
# ('Momina', 'si206', 0)
# ('Flyn', 'si206', 0)
# ('Aiden', 'si206', 0)
# ('Rhudi', 'si206', 0)
# ('Reagan', 'si206', 0)
# ('Yusuf', 'si206', 0)
# ('Tommy', 'si206', 0)
# ('Eliane', 'si206', 0)
# ('Evelina', 'si301', 1)
# ('Caiden', 'si301', 0)
# ('Katelyn', 'si301', 0)
# ('Dareh', 'si301', 0)
# ('Kaylen', 'si301', 0)
# ('Alber', 'si301', 0)
# ('Adeena', 'si301', 0)
# ('Brook', 'si301', 0)
# ('Toluwalase', 'si301', 0)
# ('Lael', 'si301', 0)
# ('Mikka', 'si301', 0)
# ('Leonie', 'si301', 0)
# ('Roxabella', 'si301', 0)
# ('Judah', 'si301', 0)
# ('Ivana', 'si301', 0)
# ('Madison', 'si301', 0)
# ('Elsbeth', 'si301', 0)
# ('Franciszek', 'si301', 0)
# ('Jaimee', 'si301', 0)
# ('Rayyan', 'si301', 0)
# ('Abraham', 'si301', 0)
# ('Kameron', 'si301', 0)
# ('Freddie', 'si301', 0)
# ('Aislinn', 'si301', 0)
# ('Ammer', 'si301', 0)
# ('Teodor', 'si301', 0)
# ('Wren', 'si301', 0)
# ('Nihaal', 'si301', 0)
# ('Jody', 'si301', 0)
# ('Chiamaka', 'si301', 0)
# ('Inika', 'si301', 0)
# ('Clodagh', 'si301', 0)
# ('Tieran', 'si301', 0)
# ('Ciar', 'si310', 1)
# ('Gracealexandra', 'si310', 0)
# ('Carys', 'si310', 0)
# ('Ker', 'si310', 0)
# ('Wasif', 'si310', 0)
# ('Khelis', 'si310', 0)
# ('Tanisha', 'si310', 0)
# ('Aulay', 'si310', 0)
# ('Diego', 'si310', 0)
# ('Ceejay', 'si310', 0)
# ('Luiza', 'si310', 0)
# ('Leiten', 'si310', 0)
# ('Zubayr', 'si310', 0)
# ('Lusiana', 'si310', 0)
# ('Ahmad', 'si310', 0)
# ('Seumas', 'si310', 0)
# ('Liva', 'si310', 0)
# ('Roman', 'si310', 0)
# ('Evonna', 'si310', 0)
# ('Jagoda', 'si310', 0)
# ('Johndean', 'si310', 0)
# ('Esma', 'si310', 0)
# ('Navneet', 'si310', 0)
# ('Marta', 'si310', 0)
# ('Reis', 'si310', 0)
# ('Aila', 'si310', 0)
# ('Chad', 'si334', 1)
# ('Jemma', 'si334', 0)
# ('Malakai', 'si334', 0)
# ('Johnjay', 'si334', 0)
# ('Nadine', 'si334', 0)
# ('Billi', 'si334', 0)
# ('Denver', 'si334', 0)
# ('Abdurraheem', 'si334', 0)
# ('Lyndsay', 'si334', 0)
# ('Aleksander', 'si334', 0)
# ('Madaki', 'si334', 0)
# ('Kyren', 'si334', 0)
# ('Eshaal', 'si334', 0)
# ('Abdirahman', 'si334', 0)
# ('Antoni', 'si334', 0)
# ('Harper', 'si334', 0)
# ('Jaimee', 'si334', 0)
# ('Cobi', 'si334', 0)
# ('Willa', 'si334', 0)
# ('Nikiya', 'si334', 0)
# ('Giyia', 'si334', 0)
# ('Lisandro', 'si334', 0)
# ('Autumn', 'si334', 0)
# ('Katriona', 'si334', 0)
# ('Isabela', 'si334', 0)
# ('Kayne', 'si334', 0)
# ('Clio', 'si334', 0)
# ('Yu', 'si334', 0)
# ('Rafif', 'si334', 0)
# ('Wezi', 'si334', 0)
# ('Jake', 'si334', 0)
# ('Jacki', 'si334', 0)
# ('Morris', 'si363', 1)
# ('Siena', 'si363', 0)
# ('Rubhan', 'si363', 0)
# ('Kayah', 'si363', 0)
# ('Kashif', 'si363', 0)
# ('Rohanne', 'si363', 0)
# ('Jazmin', 'si363', 0)
# ('Emi', 'si363', 0)
# ('Barath', 'si363', 0)
# ('Airidas', 'si363', 0)
# ('Kane', 'si363', 0)
# ('Jordan', 'si363', 0)
# ('Gianluca', 'si363', 0)
# ('Gemma', 'si363', 0)
# ('Cormac', 'si363', 0)
# ('Cathal', 'si363', 0)
# ('Rhonda', 'si363', 0)
# ('Abigayle', 'si363', 0)
# ('Averon', 'si363', 0)
# ('Mahdi', 'si363', 0)
# ('Oluwatamilore', 'si363', 0)
# ('Baighley', 'si363', 0)
# ('Lauchlin', 'si363', 0)
# ('Anwen', 'si363', 0)
# ('Doire', 'si363', 0)
# ('Paulina', 'si363', 0)
# ('Joaquin', 'si363', 0)
# ('Ceara', 'si363', 0)
# ('Cully', 'si363', 0)
# ('Kyel', 'si363', 0)
# ('Ediomi', 'si363', 0)
# ('Mirryn', 'si363', 0)
# ('Leven', 'si363', 0)
# ('Carter', 'si363', 0)
# ('Russell', 'si363', 0)
# ('Saffi', 'si363', 0)
# ('Edwin', 'si363', 0)
# ('Chad', 'si363', 0)
# ('Taddy', 'si363', 0)
# ('Sonni', 'si363', 0)
# ('Mhia', 'si363', 0)
# ('Vaila', 'si363', 0)
# ('Siyona', 'si363', 0)
# ('Elwyn', 'si363', 0)
# ('Tamzin', 'si363', 0)
# ('Kaelin', 'si363', 0)
# ('Drew', 'si363', 0)
# ('Greg', 'si363', 0)
# ('Andrea', 'si363', 0)
# ('Rhiana', 'si363', 0)
# ('Jonatan', 'si363', 0)
# ('Sakina', 'si363', 0)
# ('Faheem', 'si364', 1)
# ('Ameerah', 'si364', 0)
# ('Cormack', 'si364', 0)
# ('Darcie', 'si364', 0)
# ('Breagh', 'si364', 0)
# ('Aurelija', 'si364', 0)
# ('Aamanee', 'si364', 0)
# ('Diella', 'si364', 0)
# ('Dominik', 'si364', 0)
# ('Steven', 'si364', 0)
# ('Duaa', 'si364', 0)
# ('Amolpreet', 'si364', 0)
# ('Magnus', 'si364', 0)
# ('Keatin', 'si364', 0)
# ('Donnie', 'si364', 0)
# ('Kerr', 'si364', 0)
# ('Kiya', 'si364', 0)
# ('Renee', 'si364', 0)
# ('Jeya', 'si364', 0)
# ('Veera', 'si364', 0)
# ('Eljon', 'si364', 0)
# ('Harley', 'si364', 0)
# ('Leland', 'si364', 0)
# ('Roberta', 'si364', 0)
# ('Stefanie', 'si364', 0)
# ('Jeanie', 'si364', 0)
# ('Ina', 'si364', 0)
# ('Brea', 'si364', 0)
# ('Darrach', 'si364', 0)
# ('Kassia', 'si364', 0)
# ('Tamta', 'si364', 0)
# ('Annick', 'si364', 0)
# ('Asia', 'si364', 0)
# ('Francesca', 'si364', 0)
# ('Paidamoyo', 'si364', 0)
# ('Caelan', 'si364', 0)
# ('Innis', 'si364', 0)
# ('Aziz', 'si364', 0)
# ('Poppy', 'si364', 0)
# ('Sonia', 'si364', 0)
# ('Suilven', 'si364', 0)
# ('Kruz', 'si364', 0)
# ('Keilidh', 'si364', 0)
# ('Corin', 'si364', 0)
# ('Michael', 'si422', 1)
# ('Jaslyn', 'si422', 0)
# ('Elise', 'si422', 0)
# ('Aila', 'si422', 0)
# ('Corinne', 'si422', 0)
# ('Marina', 'si422', 0)
# ('Aiyanna', 'si422', 0)
# ('Terri', 'si422', 0)
# ('Atika', 'si422', 0)
# ('Taylan', 'si422', 0)
# ('Ellisha', 'si422', 0)
# ('Lilya', 'si422', 0)
# ('Aleese', 'si422', 0)
# ('Alina', 'si422', 0)
# ('Ceiran', 'si422', 0)
# ('Munmair', 'si422', 0)
# ('Elisia', 'si422', 0)
# ('Diego', 'si422', 0)
# ('Darn', 'si422', 0)
# ('Marios', 'si422', 0)
# ('Aislinn', 'si422', 0)
# ('Sweet', 'si422', 0)
# ('Ciar', 'si422', 0)
# ('Suman', 'si422', 0)
# ('Ashlyn', 'si430', 1)
# ('Elwyn', 'si430', 0)
# ('Jude', 'si430', 0)
# ('Savanna', 'si430', 0)
# ('Dorian', 'si430', 0)
# ('Elsa', 'si430', 0)
# ('Hosea', 'si430', 0)
# ('Rudy', 'si430', 0)
# ('Ruta', 'si430', 0)
# ('Lawrence', 'si430', 0)
# ('Emily', 'si430', 0)
# ('Kriss', 'si430', 0)
# ('Loukas', 'si430', 0)
# ('Jennifer', 'si430', 0)
# ('Rihanna', 'si430', 0)
# ('Amber', 'si430', 0)
# ('Jacqueline', 'si430', 0)
# ('Miryn', 'si430', 0)
# ('Saiba', 'si430', 0)
# ('Dilan', 'si430', 0)
# ('Kaydi', 'si430', 0)
# ('Orlagh', 'si430', 0)
# ('Famara', 'si430', 0)
# ('Sajjad', 'si430', 0)
# ('Deni', 'si430', 0)
# ('Rheo', 'si430', 0)
# ('Caceylee', 'si430', 0)
# ('Berkay', 'si430', 0)
# ('Lotus', 'si430', 0)
# ('Owais', 'si430', 0)
# ('Leilani', 'si430', 0)
